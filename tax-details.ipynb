# %%
total_income = 1450000
base_amount = 0

eps_percentage_by_company = 12
eps_percentage_by_me = 12

std_excempt = 50000
max_rent_excempt = 73000
max_excempt_under_c_nps_percentage = 10

max_deduct_under_80c = 150000
max_deduct_under_e_nps = 50000
max_deduct_under_loan_interest = 200000
max_deduct_under_parental_insurance = 25000
max_deduct_under_self_insurance = 25000

duductions_under_80c = ["PPF", "EPF", "ELSS", "Insurance(Term, saving plans, etc...)"]
