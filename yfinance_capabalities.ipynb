# %%
# !pip install yfinance

# %%
import yfinance as yf

# %%
tcs = yf.Ticker('tcs.ns')

# %%
tcs.institutional_holders
# Out:
#                                               Holder    Shares Date Reported  \
# 0                    Invesco Developing Markets Fund  31072921    2022-01-31
# 1  Vanguard International Stock Index-Emerging Ma...  14389378    2022-01-31
# 2  Vanguard International Stock Index-Total Intl ...  13442581    2022-01-31
# 3             iShares Core MSCI Emerging Markets ETF   7845215    2021-12-31
# 4             JP Morgan Emerging Markets Equity Fund   6652099    2022-01-31
# 5                             iShares MSCI India ETF   5611984    2022-01-31
# 6                               New World Fund, Inc.   5549300    2022-01-31
# 7  MFS Series Trust X-MFS Emerging Markets Equity...   4090955    2021-11-30
# 8        MFS Institutional International Equity Fund   3618539    2021-12-31
# 9                  iShares MSCI Emerging Markets ETF   3394444    2022-01-31
#
#     % Out         Value
# 0  0.0085  116096201086
# 1  0.0039   53762313552
# 2  0.0037   50224843261
# ...

# %%
tcs.major_holders
# Out:
#         0                                      1
# 0  72.21%        % of Shares Held by All Insider
# 1  16.01%       % of Shares Held by Institutions
# 2  57.61%        % of Float Held by Institutions
# 3     343  Number of Institutions Holding Shares

# %%
tcs.financials
# Out:
#                                              2021-03-31       2020-03-31  \
# Research Development                               None             None
# Effect Of Accounting Charges                       None             None
# Income Before Tax                        437600000000.0   422480000000.0
# Minority Interest                          6750000000.0     6230000000.0
# Net Income                               324300000000.0   323400000000.0
# Selling General Administrative            21310000000.0    27020000000.0
# Gross Profit                             709010000000.0   690920000000.0
# Ebit                                     424820000000.0   385810000000.0
# Operating Income                         424820000000.0   385810000000.0
# Other Operating Expenses                 222230000000.0   242800000000.0
# Interest Expense                          -6370000000.0    -9240000000.0
# Extraordinary Items                                None             None
# ...

# %%
tcs.quarterly_financials
# Out:
#                                             2021-12-31      2021-09-30  \
# Research Development                              None            None
# Effect Of Accounting Charges                      None            None
# Income Before Tax                       131910000000.0  129690000000.0
# Minority Interest                         6920000000.0    6690000000.0
# Net Income                               97690000000.0   96240000000.0
# Selling General Administrative            5730000000.0    4920000000.0
# Gross Profit                            212850000000.0  202700000000.0
# Ebit                                    122370000000.0  119910000000.0
# Operating Income                        122370000000.0  119910000000.0
# Other Operating Expenses                 72790000000.0   66710000000.0
# Interest Expense                         -2510000000.0   -1420000000.0
# Extraordinary Items                               None            None
# ...

# %%
tcs.balance_sheet
# Out:
#                                     2021-03-31    2020-03-31    2019-03-31  \
# Intangible Assets                 4.800000e+09  2.830000e+09  1.790000e+09
# Total Liab                        4.365100e+11  3.615000e+11  2.504400e+11
# Total Stockholder Equity          8.643300e+11  8.412600e+11  8.944600e+11
# Minority Interest                 6.750000e+09  6.230000e+09  4.530000e+09
# Deferred Long Term Liab           2.280000e+09  2.860000e+09  1.740000e+09
# Other Current Liab                1.329700e+11  9.520000e+10  7.629000e+10
# Total Assets                      1.307590e+12  1.208990e+12  1.149430e+12
# Common Stock                      3.700000e+09  3.750000e+09  3.750000e+09
# Other Current Assets              2.224000e+10  1.971000e+10  2.087000e+10
# Retained Earnings                 8.255800e+11  8.080600e+11  8.688900e+11
# Other Liab                        2.993000e+10  2.184000e+10  2.916000e+10
# ...

# %%
tcs.quarterly_balance_sheet
# Out:
#                                     2021-12-31    2021-09-30    2021-06-30  \
# Intangible Assets                 1.160000e+10  4.850000e+09  4.590000e+09
# Total Liab                        4.562000e+11  4.464400e+11  4.532700e+11
# Total Stockholder Equity          1.039000e+12  9.695700e+11  9.006300e+11
# Minority Interest                 6.920000e+09  6.690000e+09  6.680000e+09
# Deferred Long Term Liab           1.500000e+09  1.580000e+09  2.050000e+09
# Other Current Liab                1.452100e+11  1.395800e+11  1.421600e+11
# Total Assets                      1.502120e+12  1.422700e+12  1.360580e+12
# Common Stock                      3.700000e+09  3.700000e+09  3.700000e+09
# Other Current Assets              2.670000e+10  2.264000e+10  2.684000e+10
# Retained Earnings                 1.002530e+12  9.303400e+11  8.589500e+11
# Other Liab                        3.288000e+10  2.783000e+10  2.930000e+10
# ...

# %%
tcs.cashflow
# Out:
#                                              2021-03-31    2020-03-31  \
# Investments                               -4.670000e+10  8.389000e+10
# Change To Liabilities                      9.980000e+09  8.210000e+09
# Total Cashflows From Investing Activities -8.129000e+10  8.565000e+10
# Net Borrowings                            -1.336000e+10 -1.062000e+10
# Total Cash From Financing Activities      -3.263400e+11 -3.991500e+11
# Change To Operating Activities            -1.191000e+10 -1.690000e+10
# Net Income                                 3.243000e+11  3.234000e+11
# Change In Cash                            -1.788000e+10  1.422000e+10
# Repurchase Of Stock                       -1.972600e+11 -1.972600e+11
# Effect Of Exchange Rate                    1.730000e+09  4.030000e+09
# Total Cash From Operating Activities       3.880200e+11  3.236900e+11
# Depreciation                               4.065000e+10  3.529000e+10
# ...

# %%
tcs.quarterly_cashflow
# Out:
#                                              2021-12-31    2021-09-30  \
# Investments                               -9.070000e+10 -8.062000e+10
# Change To Liabilities                     -2.500000e+09  6.490000e+09
# Total Cashflows From Investing Activities -6.150000e+10 -7.814000e+10
# Net Borrowings                            -3.820000e+09 -3.540000e+09
# Total Cash From Financing Activities      -3.145000e+10 -3.105000e+10
# Change To Operating Activities             8.940000e+09  1.150000e+10
# Net Income                                 9.769000e+10  9.624000e+10
# Change In Cash                             7.970000e+09 -1.512000e+10
# Effect Of Exchange Rate                   -6.800000e+08 -1.180000e+09
# Total Cash From Operating Activities       1.016000e+11  9.525000e+10
# Depreciation                               1.196000e+10  1.116000e+10
# Other Cashflows From Investing Activities  3.818000e+10  9.620000e+09
# ...

# %%
tcs.earnings
# Out:
#             Revenue      Earnings
# Year
# 2018  1231040000000  258260000000
# 2019  1464630000000  314720000000
# 2020  1569490000000  323400000000
# 2021  1641770000000  324300000000

# %%
tcs.quarterly_earnings
# Out:
#               Revenue     Earnings
# Quarter
# 1Q2021   437050000000  92460000000
# 2Q2021   454110000000  90080000000
# 3Q2021   468670000000  96240000000
# 4Q2021   488850000000  97690000000

# %%
tcs.sustainability
# Out:
#                                      Value
# 2022-2
# palmOil                              False
# controversialWeapons                 False
# gambling                             False
# socialScore                           6.58
# nuclear                              False
# furLeather                           False
# alcoholic                            False
# gmo                                  False
# catholic                             False
# socialPercentile                      None
# peerCount                              105
# governanceScore                       6.88
# environmentPercentile                 None
# animalTesting                        False
# tobacco                              False
# totalEsg                             14.25
# highestControversy                       2
# esgPerformance                  UNDER_PERF
# coal                                 False
# pesticides                           False
# adult                                False
# ...

# %%
tcs.recommendations

# %%
tcs.calendar
# Out:
#                                     0                    1
# Earnings Date     2022-07-06 10:30:00  2022-07-11 10:30:00
# Earnings Average                27.01                27.01
# Earnings Low                    26.09                26.09
# Earnings High                    27.7                 27.7
# Revenue Average          526891000000         526891000000
# Revenue Low              520279000000         520279000000
# Revenue High             530550000000         530550000000

# %%
tcs.news
# Out:
# [{'link': 'https://finance.yahoo.com/news/stem-cell-global-market-growth-081800380.html',
#   'providerPublishTime': 1650010680,
#   'publisher': 'GlobeNewswire',
#   'title': 'Stem Cell Global Market Growth Opportunities: A  $18.51 Billion Market in 2026, Registering CAGR of 9.8%',
#   'type': 'STORY',
#   'uuid': '1d5e1579-2cb5-3afb-bca0-389507b5d37e'},
#  {'link': 'https://finance.yahoo.com/news/soi-finance-ecosystem-soi-plans-081700953.html',
#   'providerPublishTime': 1650010620,
#   'publisher': 'PR Newswire',
#   'title': 'Soi Finance Ecosystem(SOI) Plans To Launch A New Generation Crypto Ecosystem On The Solana Platform',
#   'type': 'STORY',
#   'uuid': '86a95185-5cc2-3e6c-b024-09027c175bf5'},
#  {'link': 'https://finance.yahoo.com/news/global-vitro-diagnostics-ivd-quality-081300810.html',
#   'providerPublishTime': 1650010380,
#   'publisher': 'GlobeNewswire',
# ...

# %%
tm = yf.Ticker('tatamotors.ns')
bs = []
years = []
bs = tm.get_info()['trailingPE']
bs
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-2990835cde29> in <module>()
#       2 bs = []
#       3 years = []
# ----> 4 bs = tm.get_info()['trailingPE']
#       5 bs
#
# KeyError: 'trailingPE'

# %%
a = bs[years[0]]['Total Current Assets']
a
# Out:
# 992800000000.0

# %%
aapl = yf.Ticker('aapl')

# %%
bs2 = aapl.get_balance_sheet()

# %%
bs2
# Out:
#                              2021-09-25    2020-09-26    2019-09-28  \
# Total Liab                 2.879120e+11  2.585490e+11  2.480280e+11
# Total Stockholder Equity   6.309000e+10  6.533900e+10  9.048800e+10
# Other Current Liab         5.357700e+10  4.786700e+10  4.324200e+10
# Total Assets               3.510020e+11  3.238880e+11  3.385160e+11
# Common Stock               5.736500e+10  5.077900e+10  4.517400e+10
# Other Current Assets       1.411100e+10  1.126400e+10  1.235200e+10
# Retained Earnings          5.562000e+09  1.496600e+10  4.589800e+10
# Other Liab                 4.305000e+10  4.610800e+10  5.050300e+10
# Treasury Stock             1.630000e+08 -4.060000e+08 -5.840000e+08
# Other Assets               3.876200e+10  3.395200e+10  3.297800e+10
# Cash                       3.494000e+10  3.801600e+10  4.884400e+10
# Total Current Liabilities  1.254810e+11  1.053920e+11  1.057180e+11
# Short Long Term Debt       9.613000e+09  8.773000e+09  1.026000e+10
# ...

# %%
abc = [['abc'],['xyz']]
for i, li in enumerate(abc):
  print(i, li)
# Out:
# 0 ['abc']
# 1 ['xyz']
