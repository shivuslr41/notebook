# %%
# !pip install pandas

# %%
import sqlite3
playground = 'drive/MyDrive/Colab Notebooks/playground/'
conn = sqlite3.connect(playground+'example.db')

# %%
import pandas as pd
df = pd.DataFrame({'col':[1, 2, 3, 4]})
df
# Out:
#    col
# 0    1
# 1    2
# 2    3
# 3    4

# %%
df.to_sql('test_table',  conn, if_exists='replace', index=False)

# %%
sql = '''select * from test_table t'''
pd.read_sql(sql, conn)
# Out:
#    col
# 0    1
# 1    2
# 2    3
# 3    4
